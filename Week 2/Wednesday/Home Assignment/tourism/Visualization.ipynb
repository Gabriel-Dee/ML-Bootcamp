# %% [markdown]
# # Visualization Assignment

# %% [markdown]
# ## Checking And Cleaning the Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
data = pd.read_csv('tourism.csv')

# %%
data.head()
# Out:
#           ID         country age_group        travel_with  total_female  \
# 0     tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1    tour_10  UNITED KINGDOM     25-44                NaN           1.0
# 2  tour_1000  UNITED KINGDOM     25-44              Alone           0.0
# 3  tour_1002  UNITED KINGDOM     25-44             Spouse           1.0
# 4  tour_1004           CHINA      1-24                NaN           1.0
#
#    total_male                         purpose     main_activity  \
# 0         1.0            Leisure and Holidays  Wildlife tourism
# 1         0.0            Leisure and Holidays  Cultural tourism
# 2         1.0  Visiting Friends and Relatives  Cultural tourism
# 3         1.0            Leisure and Holidays  Wildlife tourism
# 4         0.0            Leisure and Holidays  Wildlife tourism
#
#                     info_source tour_arrangement  ... package_transport_tz  \
# ...

# %%
data['travel_with'] = data['travel_with'].fillna('No travel with info')

data.head()
# Out:
#           ID         country age_group          travel_with  total_female  \
# 0     tour_0      SWIZERLAND     45-64    Friends/Relatives           1.0
# 1    tour_10  UNITED KINGDOM     25-44  No travel with info           1.0
# 2  tour_1000  UNITED KINGDOM     25-44                Alone           0.0
# 3  tour_1002  UNITED KINGDOM     25-44               Spouse           1.0
# 4  tour_1004           CHINA      1-24  No travel with info           1.0
#
#    total_male                         purpose     main_activity  \
# 0         1.0            Leisure and Holidays  Wildlife tourism
# 1         0.0            Leisure and Holidays  Cultural tourism
# 2         1.0  Visiting Friends and Relatives  Cultural tourism
# 3         1.0            Leisure and Holidays  Wildlife tourism
# 4         0.0            Leisure and Holidays  Wildlife tourism
#
#                     info_source tour_arrangement  ... package_transport_tz  \
# ...

# %%
data['total_female'] = data['total_female'].fillna(0)

data['total_male'] = data['total_male'].fillna(0)

data['most_impressing'] = data['most_impressing'].fillna('No comments')

data.isnull().sum()
# Out:
# ID                       0
# country                  0
# age_group                0
# travel_with              0
# total_female             0
# total_male               0
# purpose                  0
# main_activity            0
# info_source              0
# tour_arrangement         0
# package_transport_int    0
# package_accomodation     0
# package_food             0
# package_transport_tz     0
# package_sightseeing      0
# package_guided_tour      0
# package_insurance        0
# night_mainland           0
# night_zanzibar           0
# payment_mode             0
# first_trip_tz            0
# most_impressing          0
# total_cost               0
# dtype: int64

# %% [markdown]
# ## Visualization 1: Bar Chart - Visiting Countries

# %%
plt.figure(figsize=(15, 6))
tourist_type_counts = data['country'].value_counts()
plt.bar(tourist_type_counts.index, tourist_type_counts, label='Number of Tourists')
plt.title('Visiting Countries')
plt.xlabel('Country')
plt.ylabel('Number of Tourists')
plt.xticks(rotation=45)
plt.tight_layout()  # Add this line to adjust the layout
plt.legend()  # Add this line to show the legend
plt.show()

# %%
tourist_type_counts
# Out:
# UNITED STATES OF AMERICA    695
# UNITED KINGDOM              533
# ITALY                       393
# FRANCE                      280
# ZIMBABWE                    274
#                            ...
# NIGER                         1
# MYANMAR                       1
# DOMINICA                      1
# TUNISIA                       1
# ESTONIA                       1
# Name: country, Length: 105, dtype: int64
